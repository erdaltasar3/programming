# %%
T=[-12,23,0,67,34,99,-23,15]
for x in range(len(T)-1):
    c=0
    for i in T:
        if (c==len(T)-1):
            continue
        elif (T[c]>T[c+1]):
            T[c],T[c+1]=T[c+1],T[c]
        c+=1
print(T)

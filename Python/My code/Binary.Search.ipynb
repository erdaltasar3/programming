# %%
C=list(map(int,input().split()))
wanted=int(input())
for i in range(len(C)-1):
    j=0
    for g in C:
        if (j==len(C)-1):
            continue
        elif (C[j]>C[j+1]):
            C[j],C[j+1]=C[j+1],C[j]
        j+=1
print(C)
left=0
right=len(C)-1
check=0
while (check!=1):
    middle=int((left+right)/2)
    if (C[middle]==wanted):
        print(middle,". sıra")
        check=1
    elif (C[middle]>wanted):
        right=middle-1
    elif (C[middle]<wanted):
        left=middle+1
    elif (C[left]==wanted):
        print(left,". sıra")
        check=1
    elif (C[right]==wanted):
        print(right,". sıra")
        check=1
